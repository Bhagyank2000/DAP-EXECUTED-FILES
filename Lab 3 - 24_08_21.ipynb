# %%
#Food ordering/Ordering application

print("Welcome to ZWITTY!!") #app name is Zwitty
print("Cuisines 1.Chinese 2.Italian 3.Continental")
print("Select the desired Cuisine")
cuisine=int(input())
if cuisine==1:
    list1 = ['Chowmein','Noodles','Fried Rice']
    print (list1)
elif cuisine==2:
    list2 = ['Pizza','Pasta','Risotto']
    print (list2) 
elif cuisine==3:
    list3 = ['Peppered Salad','Pasta Salad']
    print (list3)

print("To add to cart press y")
a=input()
print("Add your address below")
g=input()
print("Successfully added to cart, Make Payment")
list = [150,200,300]  
sum = 0  
for i in list:  
    sum = sum+i  
print("The Amount to be paid is:",sum) 
print("COD is the only option available, Sorry for the inconvenience.Press z to confirm the order.") 
order=input()
print("Your Order have been Successfully placed..The food will be soon at your Doorsteps!!!")
# Out:
# Welcome to ZWITTY!!
# Cuisines 1.Chinese 2.Italian 3.Continental
# Select the desired Cuisine
# 3
# ['Peppered Salad', 'Pasta Salad']
# To add to cart press y
# y
# Add your address below
# r
# Successfully added to cart, Make Payment
# The Amount to be paid is: 650
# COD is the only option available, Sorry for the inconvenience.Press z to confirm the order.

# %%
#Recharge Plan

print("Do you want to rechage ? Press Y to continue")
a=input()
print("Press 1 for Prepaid or 2 for Postpaid")
b=int(input())
print("Enter mobile number")
mob=int(input())
print("select operator-press 1 for airtel, 2 for jio, 3 for vodafone")
mobi=int(input())
if mobi==1:
    oper='airtel'
elif mobi==2:
    oper='Jio'
elif mobi==3:
    oper='Vodafone'
else:
    print("Select corrent operator") 
print("Select the package by pressing 1,2 or 3")
print("1.Family pack 2.Ulimited data plan 3.Ulimited talktime")
plan=int(input())
if plan==1:
    n = int(input("Enter the number of family members "))  
    for i in range(499,500):  
        c = n*i  
        print(n,"*",i,"=",c)  
    print("The amount to be paid is",c)
elif plan==2:
    n = int(input("Enter the number of days you want to enroll this plan "))  
    for i in range(200,201):  
        e = n*i  
        print(n,"*",i,"=",e) 
    print("The amount to be paid is",e)
elif plan==3:
    n = int(input("Enter the number of days you want to enroll this plan "))  
    for i in range(50,51):  
        f = n*i  
        print(n,"*",i,"=",f) 
    print("The amount to be paid is",f)   
print("Please enter the card deatails") 
card=int(input())
print("Successfully Recharged!!!!")
# Out:
# Do you want to rechage ? Press Y to continue
# y
# Press 1 for Prepaid or 2 for Postpaid
# 1
# Enter mobile number
# 9283746565
# select operator-press 1 for airtel, 2 for jio, 3 for vodafone
# 1
# Select the package by pressing 1,2 or 3
# 1.Family pack 2.Ulimited data plan 3.Ulimited talktime
# 1
# Enter the number of family members 4
# 4 * 499 = 1996
# The amount to be paid is 1996
# Please enter the card deatails
# 5362728919156
# Successfully Recharged!!!!

# %%
#Landlord and Tenant Communication
#This is a system which has 2 parts landlord and tenant where they can login to respective slot any communicate
print("1.Landlord 2.Tenant")
print("Press 1 if your a Landlord and 2 if a tenant")
com=int(input())
if com==1:
    print("Have a safe encryped communication with Tenant!")
    print("Leave the message below for tenant")
    safe=input()
    print("The message is delivered to tenant, and will get back to you.")
elif com==2:
    print("Have a safe encryped communication with Landlord!")
    print("Leave the message below for Landlord")
    safe=input()
    print("The message is delivered to Landlord, and will get back to you.")
# Out:
# 1.Landlord 2.Tenant
# Press 1 if your a Landlord and 2 if a tenant
# 1
# Have a safe encryped communication with Tenant!
# Leave the message below for tenant
# Dear tenant, I wanted to know about water problem you are facing
# The message is delivered to tenant, and will get back to you.

# %%
#Inventory System

import os
import fileinput

def menuDisplay():
    print('===============================')
    print('= Inventory Management System =')
    print('===============================')
    print('(1) Add New Item')
    print('(2) Remove Item')
    print('(3) Update Item')
    print('(4) Search Item')
    print('(5) Print Inventory Report')
    print('(6) Quit')
    CHOICE = int(input("Enter choice: "))
    menuSelection(CHOICE)

def menuSelection(CHOICE):
    if CHOICE == 1:
        addInventory()
    elif CHOICE == 2:
        removeInventory()
    elif CHOICE == 3:
        updateInventory()
    elif CHOICE == 4:
        searchInventory()
    elif CHOICE == 5:
        printInventory()
    elif CHOICE == 6:
        exit()

def addInventory():
    InventoryFile = open('Inventory.txt', 'a')
    print("Adding Inventory")
    print("================")
    item_description = input("Enter the name of the item: ")
    item_quantity = input("Enter the quantity of the item: ")
    InventoryFile.write(item_description + '\n')
    InventoryFile.write(item_quantity + '\n')
    InventoryFile.close()
    CHOICE = input('Enter y to continue or n to exit: ')
    if CHOICE == 'y':
            menuDisplay()
    else:
        exit()
    
def removeInventory():
    print("Removing Inventory")
    print("==================")
    item_description = input("Enter the item name to remove from inventory: ")

    file = fileinput.input('Inventory.txt', inplace=True)

    for line in file:
         if item_description in line:
             for i in range(1):
                 next(file, None)
         else:
             print(line.strip('\n'), end='\n')
    item_description
    CHOICE = input('Enter y to continue or n to exit: ')
    if CHOICE == 'y':
            menuDisplay()
    else:
        exit()

def updateInventory():
    print("Updating Inventory")
    print("==================")
    item_description = input('Enter the item to update: ')
    item_quantity = int(input("Enter the updated quantity. Enter - for less: "))

    with open('Inventory.txt', 'r') as f:
        filedata = f.readlines()

    replace = ""
    line_number = 0
    count = 0
    f = open('Inventory.txt','r')
    file = f.read().split('\n')
    for i, line in enumerate(file):
        if item_description in line:
            for b in file[i+1:i+2]:
                value = int(b)
                change = value + (item_quantity)
                replace = b.replace(b, str(change))
                line_number = count
            count = i + 1      
    f.close()
    
    filedata[count] = replace + '\n'

    with open('Inventory.txt', 'w') as f:
        for line in filedata:
            f.write(line)
                                            
                
    CHOICE = input('Enter y to continue or n to exit: ')
    if CHOICE == 'y':
            menuDisplay()
    else:
        exit()

def searchInventory():
    print('Searching Inventory')
    print('===================')
    item_description = input('Enter the name of the item: ')
    
    f = open('Inventory.txt', 'r')
    search = f.readlines()
    f.close
    for i, line in enumerate(search):
        if item_description in line:
            for b in search[i:i+1]:
                print('Item:     ', b, end='')
            for c in search[i+1:i+2]:
                print('Quantity: ', c, end='')
                print('----------')
        
    CHOICE = input('Enter y to continue or n to exit: ')
    if CHOICE == 'y':
            menuDisplay()
    else:
        exit()
        
def printInventory():
    InventoryFile = open('Inventory.txt', 'r')
    item_description = InventoryFile.readline()
    print('Current Inventory')
    print('-----------------')
    while item_description != '':
        item_quantity = InventoryFile.readline()
        item_description = item_description.rstrip('\n')
        item_quantity = item_quantity.rstrip('\n')
        print('Item:     ', item_description)
        print('Quantity: ', item_quantity)
        print('----------')
        item_description = InventoryFile.readline()
    InventoryFile.close()

    CHOICE = input('Enter y to continue or n to exit: ')
    if CHOICE == 'y':
            menuDisplay()
    else:
        exit()

menuDisplay()
# Out:
# ...
# = Inventory Management System =
# ...
# (1) Add New Item
# (2) Remove Item
# (3) Update Item
# (4) Search Item
# (5) Print Inventory Report
# (6) Quit
# Enter choice: 1
# Adding Inventory
# ...
# Enter the name of the item: hello
# Enter the quantity of the item: two
# Enter y to continue or n to exit: n
